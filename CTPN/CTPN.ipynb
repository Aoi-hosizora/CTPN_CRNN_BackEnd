# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/Colab/text-detection-ctpn
# Out:
# /content/drive/My Drive/Colab/text-detection-ctpn

# %%
# !git clone https://github.com/eragonruan/text-detection-ctpn.git
# Out:
# Cloning into 'text-detection-ctpn'...
# remote: Enumerating objects: 1067, done.
# remote: Total 1067 (delta 0), reused 0 (delta 0), pack-reused 1067
# Receiving objects: 100% (1067/1067), 344.21 MiB | 19.99 MiB/s, done.
# Resolving deltas: 100% (444/444), done.

# %%
cd text-detection-ctpn/utils/bbox
# Out:
# /content/drive/My Drive/Colab/text-detection-ctpn/text-detection-ctpn/utils/bbox

# %%
# !chmod +x make.sh

# %%
# !./make.sh
# Out:
# running install
# running build
# running build_ext
# building 'bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c bbox.c -o build/temp.linux-x86_64-3.6/bbox.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from bbox.c:283:
# ...

# %%
ls
# Out:
# bbox.c                                nms.c
# bbox.cpython-36m-x86_64-linux-gnu.so  nms.cpython-36m-x86_64-linux-gnu.so
# bbox.pyx                              nms.pyx
# bbox_transform.py                     __pycache__/
# make.sh*                              setup.py

# %%
cd ../..
# Out:
# /content/drive/My Drive/Colab/text-detection-ctpn/text-detection-ctpn

# %%
# !wget https://pan.baidu.com/s/1BNHt_9fiqRPGmEXPaxaFXw

# follow setup to build the library
# download the ckpt file from googl drive or baidu yun
# put checkpoints_mlt/ in text-detection-ctpn/
# put your images in data/demo, the results will be saved in data/res, and run demo in the root
# !ls
# Out:
# checkpoints_mlt.zip  LICENSE  nets	 requirements.txt
# data		     main     README.md  utils

# %%
# !unzip checkpoints_mlt.zip
# Out:
# Archive:  checkpoints_mlt.zip
#    creating: checkpoints_mlt/
#   inflating: checkpoints_mlt/ctpn_50000.ckpt.meta
#   inflating: checkpoints_mlt/checkpoint
#   inflating: checkpoints_mlt/ctpn_50000.ckpt.index
#   inflating: checkpoints_mlt/ctpn_50000.ckpt.data-00000-of-00001

# %%
# !rm checkpoints_mlt.zip

# %%
# !python main/demo.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0722 10:15:53.915324 140297633515392 deprecation_wrapper.py:119] From main/demo.py:122: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0722 10:15:53.939966 140297633515392 deprecation_wrapper.py:119] From main/demo.py:60: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0722 10:15:53.940774 140297633515392 deprecation_wrapper.py:119] From main/demo.py:61: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0722 10:15:53.942758 140297633515392 deprecation_wrapper.py:119] From main/demo.py:64: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
# !git branch
# Out:
# * banjin-dev
